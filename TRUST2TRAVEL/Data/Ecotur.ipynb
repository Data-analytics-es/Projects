# %% [markdown]
# # Scraping Ecotur

# %%
# Importamos librerías
from bs4 import BeautifulSoup
import requests
import pandas as pd
import html
import numpy as np
import pandas as pd
from functools import reduce

# %%
#pages = np.arange(1, 7) - ya no tienen distintas paginas
count = 1
lista_casas = []
count_casa = 1 #Para el print

URL = 'https://www.ecotur.es/ecoturismo/espana'
r = requests.get(URL)
soup = BeautifulSoup(r.text, 'lxml')
    
# Guardamos lista de casas y recorremos
casas_grid = soup.find_all(class_='fot_min')

for casa in casas_grid:

    print('Casa {} de {}'.format(
        count_casa, len(casas_grid)
    ))

    URL_casas = 'https://www._______.es' + casa.find('a')['href']
    r = requests.get(URL_casas)
    soup_casa = BeautifulSoup(r.text, 'lxml')

    # Definimos id para cada cerveza
    id_casa = 'casa_' + str(count)

    # Nombre
    name = soup_casa.find(class_='titulo blq fs_21_32 mar0').text
    #print(name)

    # Direccion 
    direccion_total = soup_casa.find(class_='blq mart16 fs_14_16 lh_140').text.rsplit(' ',1)
    direccion = direccion_total[0][:-1]
    provincia = direccion_total[1]
    #print(price)

    # Categoría

    try:
        categoria = soup_casa.find(class_='bl_izq mart2 fs_12_14').text.replace('\xa0\r\n                ', '')
        categoria = categoria.replace('\r\n              ', '')
        categoria = categoria.replace('Categoría:', '')

    except:
        categoria = None

    #print(price)

    #descripcion 
    descripcion = soup_casa.find(class_='blq fs_14_18 colgen lh_140').text

    # Imagen
    div_image = soup_casa.find(class_='fot_min fot_centro marb10')

    image = 'https://www.ecotur.es' + div_image.find('img').attrs['src']
    #print(image)

    #print(ean)

   # Agregamos a la lista
    lista_casas.append([
        ('id', id_casa),
        ('name', name), 
        ('direccion', direccion),
        ('provincia', provincia),
        ('descripcion', descripcion),
        ('categoria', categoria),
        ('image', image),
        ])        


    # Pasamos al siguiente id
    count += 1
    count_casa += 1
# Out:
# Casa 1 de 106
# Casa 2 de 106
# Casa 3 de 106
# Casa 4 de 106
# Casa 5 de 106
# Casa 6 de 106
# Casa 7 de 106
# Casa 8 de 106
# Casa 9 de 106
# Casa 10 de 106
# Casa 11 de 106
# Casa 12 de 106
# Casa 13 de 106
# Casa 14 de 106
# Casa 15 de 106
# Casa 16 de 106
# Casa 17 de 106
# Casa 18 de 106
# Casa 19 de 106
# Casa 20 de 106
# Casa 21 de 106
# Casa 22 de 106
# Casa 23 de 106
# Casa 24 de 106
# Casa 25 de 106
# Casa 26 de 106
# Casa 27 de 106
# Casa 28 de 106
# Casa 29 de 106
# Casa 30 de 106
# Casa 31 de 106
# Casa 32 de 106
# Casa 33 de 106
# Casa 34 de 106
# Casa 35 de 106
# Casa 36 de 106
# Casa 37 de 106
# Casa 38 de 106
# Casa 39 de 106
# Casa 40 de 106
# Casa 41 de 106
# Casa 42 de 106
# Casa 43 de 106
# Casa 44 de 106
# Casa 45 de 106
# Casa 46 de 106
# Casa 47 de 106
# Casa 48 de 106
# Casa 49 de 106
# Casa 50 de 106
# Casa 51 de 106
# Casa 52 de 106
# Casa 53 de 106
'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=12316088_1716016011964679_2592902739.jpg&c=9371')],
#  [('id', 'casa_5'),
#   ('name', "O Chardinet d'a Formiga"),
#   ('direccion', 'C/Única, s/n, Charo  22336 La Fueva'),
#   ('provincia', 'Huesca'),
#   ('descripcion',
#    'Casa rural en el Pirineo aragonés cerca de Parque Nacional de Ordesa y Monte Perdido'),
#   ('categoria', 'Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=7-1-768x53310.jpg&c=22981')],
#  [('id', 'casa_6'),
#   ('name', 'Casa Insol'),
#   ('direccion', 'C/ Única nº 10  22474 Denuy'),
#   ('provincia', 'Huesca'),
#   ('descripcion',
#    'Si eres amante de la Naturaleza en estado puro, este es tu lugar.\nCasa Insol\xa0es una casa rural de categoría superior, basada en bioconstrucción\xa0 y sostenible.\nEstamos en Denuy, típica población pirenaica inmersa en un paraje natural de incomparable belleza. Cuenta con un pintoresco casco urbano que se distribuye de manera escalonada y de arquitectura montañesa. Un lugar donde la vida es silenciosa, tranquila y que mantiene su estado natural. Pertenece al Municipio de Las Paules en la Ribagorza y está ubicado en el Valle del Baliera, también conocido como el Valle de Castanesa. El principal objetivo cuando pensamos en este proyecto. Mejorar en calidad de vida, de hecho, dejamos nuestra ciudad natal y nos vinimos al Pirineo Aragonés, para realizar este largo sueño, y así compartir y\xa0 trasmitir, nuestro respeto por el medio ambiente y el amor a la Naturaleza. Los servicios que ofrecemos básicamente\xa0son:\xa0alojamiento, desayunos, cenas y asesoramiento sobre excursiones ya sean de naturaleza\xa0o culturales.\nLugares de interes muy cercanos a nuestro enclave.- El parque tematico de Las Brujas en Laspaules, El Parque Natural Poset-Maladeta en el Valle de Benasque. El Parque Nacional Aigües-Tortes y el Románico de la Vall de Boi, el Llauset, el hayedo de Selenques, El Turbón, El Valle de Aran. La Roda de Isabena........\xa0'),
#   ('categoria', 'Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=DSCN337567.70093.jpg&c=25297')],
#  [('id', 'casa_7'),
#   ('name', 'La Borda de Formigales'),
#   ('direccion',
#    'Carretera de Graus. De Palo a Formigales Km. 1  22336 Formigales, Fueva (La)'),
#   ('provincia', 'Huesca'),
#   ('descripcion',
#    'la Borda de Formigales es una casa de aperos con 1 ha de terreno, restaurada siguiendo criterios de sostenibilidad y autosuficiencia que utiliza energías renovables, asegurando la confortabilidad y bienestar total del visitante.\xa0Se trata, probablemente de una de las pocas casas de turismo rural autosuficientes del sobrarbe. El objetivo prioritario de la casa ha sido siempre su autonomía de manera que garantice la menor huella de contaminación posible. Disponemos de placas solares para la iluminación, para la bomba del agua, la nevera y permite también cargar móviles y ordenadores. El agua es recogida de la lluvia y acumulada en un aljibe de 10.000L.'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=11351183_653036108165638_83561532746.png&c=29741')],
#  [('id', 'casa_8'),
#   ('name', 'Turismo Rural La Ojinegra'),
#   ('direccion', 'C/ La Iglesia nº 21  44509 Alloza'),
#   ('provincia', 'Teruel'),
#   ('descripcion',
#    'Turismo rural La Ojinegra, es una casa rural de categoría superior que dispone de tres amplias habitaciones dobles. Destaca además por su restaurante ecológico El Morral de La Ojinegra, con su cocina a fuego de leña, platos con ingredientes ecológicos certificados, de proximidad y de comercio justo y con la mención "restaurante Km0" de Slow Food por lo que adquiere un compromiso para fomentar la biodiversidad y promover la cultura alimentaria.'),
#   ('categoria', 'Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=Restaurante-km08964.jpg&c=15818')],
#  [('id', 'casa_9'),
#   ('name', 'Mas La Llum'),
#   ('direccion',
#    'Mas la Llum, la casa de palla  44622 Arens de Lledó (Cerca de Los puertos de Beceite)'),
#   ('provincia', 'Teruel'),
#   ('descripcion',
#    'Mas la Llum es una Casa de Ecoturismo rural y aula de formación, autoconstruida con elementos naturales, balas de paja, madera, revocos de barro y pinturas de arcillas naturales. Todo ello bajo criterios de casa sana, libre de tóxicos, aportando calidez, bienestar y salud a las personas alojadas.Mas la Llum es una edificación autosuficiente y bioclimática, orientada y pensada para aprovechar de forma eficiente los recursos naturales, minimizando así el consumo de CO2, y la gestión de la finca se realiza bajo criterios de sostenibilidad medioambiental y social.Un lugar para disfrutar al máximo del paisaje de montaña, de la diversidad de flora y fauna salvaje, de la tradición gastronómica de la zona, de los fantásticos pueblos medievales y de cultura tradicional entre otros.'),
#   ('categoria', 'Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=IMG_20190601_091800811.jpg&c=25991')],
#  [('id', 'casa_10'),
#   ('name', 'La Posada del Valle'),
#   ('direccion', 'Collía  33549 Arriondas'),
#   ('provincia', 'Asturias'),
#   ('descripcion',
#    'Hotel Posada del Valle, Casona asturiana de piedra y madera, construida a finales del siglo XIX y rehabilitada con fidelidad arquitectónica. Su decoración se inspira en el equilibrio entre lo moderno y lo rústico. Nacho y Joann han logrado un confortable y acogedor establecimiento en el que se precian un característico salón con chimenea, una sala de lectura panorámica y terrazas con vistas al los Picos de Europa. El restaurante con amplias vistas, ofrece desayunos con panes recién hechos complementados con productos artesanales, y cenas a preaviso basadas en una cocina imaginativa y en la que se acentúa el uso de productos de la zona y ecológicos. El Hotel está rodeado por su propia finca de 80,000 m2 sobre la ladera sur de un pequeño valle junto al Paisaje Protegido del Sueve. Está situado en Collia a 2,5 Km de Arriondas. Los valores medio ambientales constituyen una parte central de su filosofía, contribuyendo así a crear un ambiente agradable, promoviendo el bienestar y el disfrute de huéspedes. En este sentido también se ruega no fumar dentro del hotel.'),
#   ('categoria', 'Hotel'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=Hotel_Posada_del_Valle_-1224.jpg&c=514')],
#  [('id', 'casa_11'),
#   ('name', 'Palacio Florez Estrada'),
#   ('direccion', 'C/Flórez Estrada s/n  33840 Pola de Somiedo'),
#   ('provincia', 'Asturias'),
#   ('descripcion',
#    'En la casona, junto a la que hay una capilla del XVIII, se dispone de 7 habitaciones dobles y 2 individuales, además de dos salones de uso compartido. Al lado, un antiguo horno de pan rehabilitado en habitación doble superior. Debajo de la casa disponen de una sala polivalente donde realizan encuentros y talleres. Los jardines, con una piscina y antiguo palomar a un lado, ofrecen un espacio perfecto de descanso junto al río. Detrás de la casa hay una pista de tenis, baloncesto y fútbol al aire libre y, junto a ella, una huerta de cultivo ecológico que utilizan como taller para los más pequeños y mayores a modo de espacio de educación ambiental. Igual ocurre con los árboles del entorno como pinos, pinzapos, abetos y manzanos.Delante, 4 apartamentos rehabilitados que eran antiguas cuadras, y uso compartido de los espacios comunes. Todo ello en Somiedo, Parque Natural y Zona de la Biosfera desde hace 20 años.Este hotel integrado en Casonas Asturianas desde el año 1995 ha pasado recientemente a una nueva gestión, de la mano de Manuel hijo de la antigua propietaria, quien se ha trasladado a vivir a Somiedo junto con su familia desde hace más de un año, apostando por generar un espacio de reflexión, debate y retiro a partir de talleres sobre diferentes temáticas y la puesta en marcha de actividades relacionadas con el descanso y el reposo, además de estar muy involucrados en actividades de promoción de derechos de la infancia.'),
#   ('categoria', 'Hotel'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=
),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=tauran2561.jpg&c=555')],
#  [('id', 'casa_23'),
#   ('name', 'Can Martí Agroturismo'),
#   ('direccion',
#    '\xa0San Joan de Labritja  07810 San Joan de Labritja (Ibiza)'),
#   ('provincia', 'Ibiza'),
#   ('descripcion',
#    'El Hotel Agroturismo Can Martí se encuentra en el norte de la isla, en una zona todavía preservada del turismo de masas. La finca dispone de una superficie de 11 hectáreas y una situación idílica en un pequeño valle rodeado de colinas boscosas. Un paisaje auténtico de terrazas, muros de piedra, tierra roja, numerosos árboles y una tranquilidad absoluta. La casa varias veces centenaria, ha sido sometida a una renovación completa pero suave, respetando la arquitectura local. En la medida de lo posible hemos utilizado materiales tradicionales y ecológicos.'),
#   ('categoria', 'Hotel'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=Can_Marti357.jpg&c=512')],
#  [('id', 'casa_24'),
#   ('name', 'Son Lladó'),
#   ('direccion', 'Camí des Palmer, km. 2,300  APT 157  07630 Campos'),
#   ('provincia', 'Mallorca'),
#   ('descripcion',
#    'Son Lladó es una finca agrícola en activo de explotación familiar, con varias casas o apartamentos rurales para alquiler turístico. Les presentamos una auténtica Possessió de Mallorca cuyas edificaciones datan del siglo XVII y que desde el año 2000, además de desarrollar las actividades agrícola-ganaderas propias, dispone de una atractiva oferta turística, en un enclave privilegiado de Mallorca.Una filosofía de vacaciones con valores añadidos y una familia nativa, atenta a sus necesidades, que velará para que en su visita a Mallorca la estancia en la Finca Son Lladó resulte inolvidable.'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=son_llado123.jpg&c=22119')],
#  [('id', 'casa_25'),
#   ('name', 'Posada Molino del Canto'),
#   ('direccion', 'Molino del Canto s/n  09146 Barriolacuesta'),
#   ('provincia', 'Burgos'),
#   ('descripcion',
#    'La Posada se encuentra situada en un precioso rincón del Valle de Zamanzas, en la orilla del río Ebro, a cincuenta metros del molino que la da nombre. Durante cientos de años fue el lugar de trabajo de los molineros, y ahora, tras una cuidada restauración, la hemos convertido en un lugar de descanso. Para la restauración de los edificios, se ha tenido en cuenta todos aquellos aspectos que hacen que la posada esté totalmente integrada en el medio que la rodea, acorde en materiales de construcción con los propios de la zona, madera de roble y piedra caliza. La finca consta de tres edificios, la antigua vivienda, hoy Posada, donde se encuentran las habitaciones, el salón-comedor y la cocina. La antigua hornera, hoy oficina. Y el maravilloso Molino, hoy restaurado y arreglado , sigue siendo el Molino, aunque ahora ya nadie trae trigo a moler, pero podrás ver su funcionamiento. Al igual que la construcción de la Posada, hemos procurado vestirla en su interior con muebles y elementos antiguos y restaurados. En la planta baja, el recibidor, con una pequeña biblioteca, especializada en libros de rutas, aves y etnografía de la comarca, nos da paso al salón con chimenea francesa y comedor con capacidad para doce personas, ó dieciocho en el caso de grupos. La escalera de olmo da acceso a la primera planta en la que se encuentran las seis habitaciones, al ser todas tipo dúplex, se entra primero en un salón privado y en la planta superior está el dormitorio y el baño con bañera, esta planta superior está abuhardillada y cuenta con una gran ventana en el tejado que aporta luz y romanticismo en las noches con luna. Tenemos habitaciones con camas de matrimonio y otras con dos camas, en cualquiera de los dos casos las camas son amplias y vestidas con sábanas y colchas de algodón. Todas las habitaciones tienen la posibilidad de instalar camas supletorias, por lo que la capacidad y distribución puede ser variada, consúltanos para grupos o familias. En el exterior hay un porche y un amplio jardín al lado del río Ebro, así como un gigantesco nogal que nos da frescor en verano.'),
#   ('categoria', 'Hotel'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=Molino_del_canto3854.jpg&c=19725')],
#  [('id', 'casa_26'),
#   ('name', 'Sabinares del Arlanza'),
#   ('direccion', 'C/ Las Turriendas 70  09347 Puentedura.'),
#   ('provincia', 'Burgos'),
#   ('descripcion',
#    'Hotel Rural bioclimático y sostenible, ubicado en Puentedura, junto al río Arlanza, a medio camino entre Lerma y Covarrubias, en la provincia de Burgos. Es un espacio innovador que amplía la oferta turística de la comunidad de Castilla y León. Os invitamos a practicar agroturismo conociendo nuestro proyecto y sus peculiaridades y el ecoturismo, ese turismo orientado a la naturaleza disfrutando del espectacular entorno que nos ofrece el parque natural de "La Yecla y los Sabinares del Arlanza".'),
#   ('categoria', 'Casa Rural de alquiler integro  | Hotel'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=12196252_904666452915943_68537316567.jpg&c=18489')],
#  [('id', 'casa_27'),
#   ('name', 'Casa de Cuento La Mallada'),
#   ('direccion',
#    'Camino del Monte, 7 Barrio de Orbanajo (Ozuela)  24415 Ponferrada'),
#   ('provincia', 'León'),
#   ('descripcion',
#    'Casa de cuento, mágica, en plena naturaleza, artesana y rústica, rodeada de jardines naturales con pradera en entorno de bosque, enclavada en los protegidos montes aquilianos desde donde se domina la amena llanura berciana con sus picos mas altos. Casa de piedra y maderas nobles, tejado de pizarra a granel aislado con corcho natural, radiadores, herrajes de forja con canalones de cobre.Casa sana, restaurada artesanalmente en estilo rústico con productos ecológicos. Biblioteca, dvd, equipo de musica, lavavajillas. Wifi, admite animales, bicicletas y cunas disponibles. Cerca de rios y pistas de esquí.'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=P8202632_(2)50.jpg&c=882')],
#  [('id', 'casa_28'),
#   ('name', 'Casas Rurales de Caín'),
#   ('direccion', 'C/ Gregorio Pérez de María, 27B  24915 Caín de Valdeón'),
#   ('provincia', 'León'),
#   ('descripcion',
#    'LEÓN. Las casas rurales ecológicas están situadas en Caín, en el corazón de los PICOS DE EUROPA, en el Valle de Valdeón o Valle de Eigon, como consta en los documentos a partir del siglo X. Es un valle de alta montaña producto de la erosión de los antiguos glaciares laterales y excavado por el río Cares de sur a norte; está enclavado en un circo calizo entre los macizos occidental y central, de los Picos de Europa.\nDos casas rurales\xa0ecológicas\xa0Mesones y\xa0 Mueño\xa0(ambas de 2-4 pl.) perfectas para dos personas\xa0que disponen de categoría de Casa Rural de cuatro estrellas otorgada por la Junta de Castilla y León a los alojamientos rurales. Asegura los mejores estándares de calidad, equipamiento, confort, limpieza, entorno, seguridad, gestión de los procesos de mejora continua, etc. Por eso, los alojamientos rurales de cuatro estrellas verdes como las Casas Rurales de Caín, te garantizan la calidad que vas buscando en tu alojamiento vacacional.'),
#   ('categoria',
#    'Casa Rural de alquiler integro  | Actividad en la Naturaleza'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=fachada173.jpg&c=31891')],
#  [('id', 'casa_29'),
#   ('name', 'Agroturismo El Mirador de la Cigüeña'),
#   ('direccion',
#    'C/ Cigüeña, 6 Bis  40160 Cabanillas del Monte (Torrecaballeros)'),
#   ('provincia', 'Segovia'),
#   ('descripcion', 'PROYECTO FAMILIAR CON VALORES. CONOCER PARA CONSERVAR'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=IMG_20180621_1058207663.jpg&c=21490')],
#  [('id', 'casa_30'),
#   ('name', 'Tenada del Monte'),
#   ('direccion', 'C/ Cigüeña, 6  40160 Cabanillas del Monte (Torrecaballeros)'),
#   ('provincia', 'Segovia'),
#   ('descripcion', 'CONOCER PARA CONSERVAR'),
#   ('categoria', 'Actividad en la Naturaleza'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=tenada67.png&c=21520')],
#  [('id', 'casa_31'),
#   ('name', 'Hotel Enoturismo Mainetes'),
#   ('direccion', 'Paraje Mainetes, s/n  02651 Fuenteálamo'),
#   ('provincia', 'Albacete'),
#   ('descripcion',
#    'ALBACETE.\xa0Hotel Rural ENOTURISMO MAINETES\xa0cuenta con 14 habitaciones dobles con climatización y baño privado, restaurante con productos ecológicos y locales , cafetería con chimenea , bodega y SPA. La finca\xa0y la bodega cuentan con su certificación ecológica. Dispone de huerto ecológico y ofrece productos locales y de elaboración propia.\nMuseo etnográfico y enológico en el propio hotel. A 20 min. de la Reserva Natural Laguna Salada de Pétrola, paraje protegido por la anidación de flamencos.'),
#   ('categoria',
#    'Restaurante  | Casa Rural de alquiler integro  | Hotel  | Finca familiar, bodega, almazara  | Actividad en la Naturaleza'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=paisaje2.100024.jpg&c=31937')],
#  [('id', 'casa_32'),
#   ('name', 'Casa Rural El Arco'),
#   ('direccion', 'C/ La Iglesia nº 22  45574 La Estrella'),
#   ('provincia', 'Toledo'),
#   ('descripcion',
#    'Casa rural de construcción tradicional, rehabilitada con criterios bioclimáticos y tratamientos ecológicos. Para favorecer el descanso, se han utilizado materiales naturales tratados con respeto, que hacen un ambiente saludable y reconfortante. Situada en la comarca de la Jara, en la provincia de Toledo y limitando con Extremadura es una zona cuya despoblación es cada vez mayor. El objetivo es fomentar nuestro futuro a través del turismo sostenible, dando a conocer nuestro pasado y nuestro entorno. Situada en un paisaje de dehesa y montes bajos contamos con una rica fauna: ciervos, corzos, buitres, águilas, especies que se podrán observar fácilmente por los diversos recorridos que se pueden hacer por las rutas y senderos señalizados y por el camino natural de la Vía Verde de la Jara. La vegetación característica es jara, tomillos, retamas, espinos y gran cantidad de plantas medicinales. Bajo encargo contamos con servicio de Restauración. Con productos de proximidad y ecológicos en su mayor medida. Se ofrece información de las actividades que se pueden realizar por la zona, así como los recorridos dependiendo del gusto de los visitantes.'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=elarco90.png&c=29630')],
#  [('id', 'casa_33'),
#   ('name', 'Casa rural Santa Barbara'),
#   ('direccion', 'Calle Juan de Dios Díaz, 67  45640 El Real de San Vicente'),
#   ('provincia', 'Toledo'),
#   ('descripcion',
#    'Situados en la Sierra de San Vicente, en nuestra casa hemos tenido en cuenta el entorno en el que nos encontramos ofreciendo calidad y comodidad pero respetando la naturaleza (Natura 2000 y protección de aves) podéis disfrutar de la casa de alquiler completo con cuatro habitaciones dobles, dos baños, cocina totalmente equipada y un amplio patio con barbacoa y piscina de agua salada.\n'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=casa_189086.jpg&c=30939')],
#  [('id', 'casa_34'),
#   ('name', 'Cal Calsot Casa Rural'),
#   ('direccion', 'C/ Tossal 2  Montellà de Cadí  25725 Montellà i Martinet'),
#   ('provincia', 'Lleida'),
#   ('descripcion',
#    'Un día decidimos vivir lejos de la ciudad, a un ritmo más pausado y de manera más sostenible.Cal Calsot nos ha permitido cumplir nuestro sueño, inventando un espacio donde vivir y poder compartir contigo.Ahora la antigua masía del siglo XIX es una pequeña casa rural ecológica y responsable, entre las montañas del Parque Natural del Cadí-Moixeró y los Pirineos, en la comarca de la Cerdanya, donde cuidamos a los huéspedes como amigos y cuidamos de nuestro entorno como si fuera nuestra casa.Somos Lidia y Marc y estaremos encantados de tenerte en casa!\nEl año 2012 pusimos en marcha Cal Calsot, una casa rural, con capacidad para 12 personas, distribuidas en 4 habitaciones dobles, y 1 una suite para 2, 3 o 4 personas.Nos encontrarás en Montellà, un pequeño pueblo de montaña, pequeño y tranquilo, a 1.158 m. de altitud, a los pies de la sierra del Cadí. Un entorno idóneo para que puedas\xa0desconectar y disfrutar de la naturaleza, practicando senderismo, BTT, recorriendo rutas en bicicleta o a caballo, observando aves\xa0o visitando alguna de las granjas o artesanos locales, descubriendo todo nuestro legado histórico, arquitectónico y artístico.\nSabemos que buscas tranquilidad, por ese motivo hemos creído oportuno limitar la edad, así pues, los menores deben tener como mínimo 12 años y podréis alojaros en la habitación familiar.'),
#   ('categoria', 'Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=Cal_Calsot_Casa_Rural_Hivern_Cerda053.jpg&c=22486')],
#  [('id', 'casa_35'),
#   ('name', 'Cerdanya EcoResort'),
#   ('direccion', 'Crer Puig, 3  25727 Prullans'),
#   ('provincia', 'Lleida'),
#   ('descripcion',
#    'Disfruten de uno de los alojamientos del Cerdanya Resort (Hotel Muntanya & SPA*** - Aparthotel Ca L"Auren - Camping Bungalow Park La Cerdanya) con vistas preciosas al Parc Natural Cadí- Moixeró. Descubran la magia del Pirineo Catalán con las excursiones guiadas, déjense mimar en la zona Wellness, visiten nuestra granja educativa y aprovechen los múltiples servicios para toda la familia.'),
#   ('categoria', 'Hotel'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=cerdanya60.png&c=526')],
#  [('id', 'casa_36'),
#   ('name', 'El Molí de Can Aulet'),
#   ('direccion', 'El Moli de Can Aulet s/n  17401 Arbúcies'),
#   ('provincia', 'Girona'),
#   ('descripcion',
#    'FINCA Y GANADO AVALADOS POR EL CONSEJO CATALAN DE PRODUCCIÓN DE AGRICULTURA ECOLÓGICA Dos pequeñas casas independientes, "el Cirerer" y "l"Estada", rodeadas de jardines y de un porche con barbacoa y anexa a la casa principal, con orígenes en 1547. Finca con prados y pastos, integrada en el conjunto del Molí de ca n"Aulet, incluida dentro del plan de espacios de interés natural por su riqueza y biodiversidad. Situados a medio camino del corredor Montseny-Guilleries podréis disfrutar, durante todo el año, de paseos y excursiones por los bosques centenarios, o por las más de cien fuentes de los alrededores de Arbúcies y de Sant Hilari Sacalm.'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=Can_Aulet81.jpg&c=28096')],
#  [('id', 'casa_37'),
#   ('name', 'Arruan-Haundi'),
#   ('direccion', 'Lastur Behea Auzoa, 6  20829  ItziarDeba'),
#   ('provincia', 'Guipuzcoa'),
#   ('descripcion',
#    'La actividad principal\xa0de Arruan-Haundi es la agro-ganadería ecológica. Nos esforzamos por recuperar animales autóctonos o de razas antiguas. Son parte de nuestro caserío también la huerta, el agroturismo y las instalaciones de energías renovables.\nSituación: 6 km. de la costa (Deba, Mutriku) por el monte, (sendero señalizado hasta el mar).Es Centro Geográfico del País por la costa: "50 km. aproximados" de Donostia-San Sebastian, Bilbao y Vitoria-Gasteiz.'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=arruan84.png&c=6364')],
#  [('id', 'casa_38'),
#   ('name', 'Agroturismo Arkaia'),
#   ('direccion', 'Arkaia, 13 C  01193 Arkaia'),
#   ('provincia', 'Álava'),
#   ('descripcion',
#    'Agroturismo Arkaia es fruto de una rehabilitación minuciosa y laboriosa del edificio original del siglo XIX que ha conservado la arquitectura tradicional, dando como resultado una casa rural de alquiler completo con capacidad para 5-9 personas, cómoda, moderna totalmente accesible, sostenible y comprometida con el medio ambiente.Dada su cercanía a Vitoria-Gasteiz (a 5 km. del centro histórico), permite aprovechar las numerosas propuestas de la capital de Euskadi, designada Capital Verde Europea 2012. Agroturismo Arkaia dispone de la Q de calidad turística y Ecoetiqueta'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=Agroturismo_Arkaia9.jpg&c=22244')],
#  [('id', 'casa_39'),
#   ('name', 'Hotel Mundaka'),
#   ('direccion', 'C/ Florentino Larrinaga, 9  48360 Mundaka'),
#   ('provincia', 'Bizkaia'),
#   ('descripcion',
#    'El Hotel Mundaka comenzó su actividad en 1995, rehabilitando un edificio del centro de Mundaka catalogado como edificio histórico, y desde entonces nuestra preocupación ha sido ir mejorando para ofrecerles la mejor estancia en nuestra villa, que es un paraíso para los que practican Surf y para las familias. Todos los que nos visitéis, tendréis la oportunidad de disfrutar de un hotel familiar, situado en el casco viejo de Mundaka, en el corazón de la Reserva de la Biosfera de Urdaibai y a pocos metros de la internacionalmente conocida "ola de izquierda", una de las mejores olas del mundo para la práctica del surf.\nEl ambiente es acogedor y tranquilo, las habitaciones son cálidas y el trato procuramos que sea cercano y amable.Somos un hotel sostenible y por ello utilizamos productos ecológicos para la limpieza y reciclamos la práctica totalidad de los residuos del hotel, así como llevamos a cabo medidas de ahorro energético y de agua. Desde hace algún tiempo, disponemos de placas solares, que cubren nuestro consumo de agua caliente.En el entorno podréis disfrutar de actividades como la práctica del surf, buceo, paseos marítimos en barco o velero, paseos a caballo, Btt, senderismo, así como conocer la cultura, tradiciones y gastronomía del país vasco.En nuestro pequeño pueblo pesquero tendrán la oportunidad de visitar el mirador de Portuondo con una de las mejores panorámicas de la ría, la ermita de Santa Catalina, la isla de Izaro y a tan solo 11km, el biotopo protegido de San Juan de Gaztelugatxe.No se olviden de degustar alguno de los muchos pintxos que ofrecen los bares de la localidad, regados con un Txakoli de la comarca.'),
#   ('categoria', 'Hotel'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=mundaka4.jpg&c=23012')],
#  [('id', 'casa_40'),
#   ('name', 'Ecoagroturismo Arqueixal'),
#   ('direccion', 'Granxa Arqueixal. Santiago de Albá  27207  Palas de Rei'),
#   ('provincia', 'Lugo'),
#   ('descripcion',
#    'Granja familiar de producción artesanal de queso, yogur y leche ecológico con actividades turísticas asociadas a la recuperación de un conjunto de 5 edificios tradicionales rehabilitados de acuerdo a criterios de bioconstrucción y un espacio multiusos para talleres, encuentros y charlas.\n4 casas están recuperadas para alojamientos rurales, antiguos edificios de arquitectura popular. Divulgamos la cultura tradicional y popular galega através de la recuperación de tradiciones ancestrales, de talleres de artesania y la promoción de actividades rurales en extinción.'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=arqueixal8.jpg&c=22729')],
#  [('id', 'casa_41'),
#   ('name', 'Reitoral de Chandrexa'),
#   ('direccion',
#    'Barrio Casalta, 6A  32747 Chandrexa (Santa Maria) (Parada de Sil)'),
#   ('provincia', 'Ourense'),
#   ('descripcion',
# ...
#    'El alojamiento rural está a pocos metros de la linde norte del parque nacional y frente a una de sus más bellas umbrías, perteneciente a la misma finca y que se encuentra coronada por el Puerto de la Serrana.\nDispone de 6 habitaciones dobles tipo suites, cada una con su pequeño saloncito en el que existe bajo un sofá una tercera cama con lo que se puede convertir cada habitación en ocupación para tres personas.\nSenderismo dentro de la propia finca. Astroturismo desde la misma casa rural, con un cielo espectacular gracias al emplazamiento de nuestro establecimiento y a la pureza de los cielos en esta zona. Paseos micológicos en temporada. Visita a la explotación de la finca. Alquiler de bicicletas. Juegos populares.'),
#   ('categoria', 'Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=casa_rural_con_pisci365793.jpg&c=2527')],
#  [('id', 'casa_91'),
#   ('name', 'Pagorriaga'),
#   ('direccion', 'Pagorriaga  20200 AratxMatxinbenta'),
#   ('provincia', 'Gipuzkoa'),
#   ('descripcion',
#    'El caserío Pagorriaga se halla en lo que en Euskadi se denomina espacio de interés Naturalístico: Espacio de Murumendi. Está a una altura de 700 metros, con unas vistas paisajísticas excepcionales. Atalaya donde se divisa el mar, la cordillera del Amboto, la mayoría de los montes del sur y noroeste guipuzcoanos, a las faldas del Murumendi y asomado al barranco donde empieza el biotopo de Beizama, robledal de mayor extensión de Guipuzcoa. El subsuelo kárstico, ha creado cuevas, simas, dolinas, fuentes y riachuelos con cascadas. La flora se enriquece de acebos, tejos, hayas, robles, fresnos y en estos momentos, praderas limpias por la acción de los ciervos. La fauna también es muy variada; jabalíes, zorros, tejones, gatos monteses, corzos y toda clase de aves, y en los riachuelos, truchas. La base ganadera lo conforma el rebaño de ciervas (50), 4 machos adultos y los gabatos o cervatillos nacidos en el año. Además nos encontramos con algunas ovejas, cabras enanas y todo tipo de aves de corral. El caserío se abastece de energía solar y eólica y, como combustible, la leña.'),
#   ('categoria', 'Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=fachada_agroturismo_pagorriaga7465.jpg&c=19877')],
#  [('id', 'casa_92'),
#   ('name', 'Agroturismo Erlete Goikoa'),
#   ('direccion', 'Barrio Mardari, 5  20829 Itziar'),
#   ('provincia', 'Gipuzkoa'),
#   ('descripcion',
#    'Un caserío renovado manteniendo la piedra y madera original. Situado en el Geoparkea de la Costa Vasca. Tenemos un viñedo, hacemos Txakoli y pertenecemos a la DO Getariako Txakolina. Tenemos una plantación de manzana autóctona y hacemos sidra y zumo natural. Tenemos vacas y ovejas de raza local.\nSituados en el mismo Geoparque de la Costa Vasca, el Camino de Santiago pasa a 20 metros de nuestro Agroturismo.\nContamos con 3 habitaciones dobles con cama supletoria. Una adaptada para minusválidos en planta baja y 2 loft con cocina ideal para familias. Tienen baño propio y conexión Wi-Fi gratuita. Todas ellas tienes decoración rústica moderna con paredes de piedra vista y techos de madera.\nSomos colaboradores del Geoparke de la Costa Vasca. Informamos de actividades locales a nuestros clientes, así como visitas a Queserías locales, paseos por circuitos del Geoparke...'),
#   ('categoria', 'Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=_10406822249.jpg&c=30557')],
#  [('id', 'casa_93'),
#   ('name', 'Caserio Sarasola Zahar'),
#   ('direccion',
#    'Caserio Sarasola Zahar, barrio zehatz, 10  20749 Aizarnazabal'),
#   ('provincia', 'Guipuzcoa'),
#   ('descripcion',
#    'Típico caserío\xa0del S. XVIII en el que los propietarios han querido mantener su carácter de sobriedad y sencillez a la vez que acogedor. Disfrute del silencio del entorno paseando por los bosques y campos que lo rodean y de sus vistas al mar cantábrico.\nOfrece alojamiento, desayunos, cenas (bajo petición), masaje,venta de productos con label ecológico y la posibilidad en temporada baja de realizar trabajos agrícolas.\nCasa Rural por Habitaciones con capacidad para 14 personas\xa0dispone de 6 habitaciones dobles, 3 baños, salón con estufa y cocina. Se encuentra rodeada de una zona ajardinada y con vistas al mar, se halla rodeada de verdes campos y bosques.\n'),
#   ('categoria', 'Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=facha300088.jpg&c=31319')],
#  [('id', 'casa_94'),
#   ('name', 'Kukuma Etxea'),
#   ('direccion', 'Erdiko Auzoa 5  01208 Galarreta  Alava'),
#   ('provincia', 'Araba'),
#   ('descripcion', '\xa0Refugio de montaña de lujo'),
#   ('categoria',
#    'Casa Rural de alquiler integro  | Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=IMG_20180925_1511023635.jpg&c=29745')],
#  [('id', 'casa_95'),
#   ('name', 'Ekolanda'),
#   ('direccion', 'Calle San Martín, 27  31697 Esnotz'),
#   ('provincia', 'Navarra'),
#   ('descripcion',
#    'Ekolanda es una antigua borda construida en el año 1842 convertida en una casa rural de cuatro habitaciones con encanto y un salón comedor con chimenea para disfrutar de unos días inolvidables y proporcionar descanso y un poco de paz a nuestro cuerpo y mente.\nEstá totalmente rehabilitada y ha sabido mantener la esencia y la historia del Valle de Erro, uno de los grandes paraísos naturales de Navarra, para los amantes de la naturaleza, en él se pueden recorrer multitud de senderos que nos adentran en el Pirineo.\nUn lugar para descubrir y redescubrirse!!!\n\nTe esperamos en Ekolanda... Veronica y Estefania.'),
#   ('categoria', 'Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=1_9643.50031.jpg&c=2527')],
#  [('id', 'casa_96'),
#   ('name', 'Pou de Beca Allotjaments i agroturisme'),
#   ('direccion', 'Masia Beca, nº 11  12194 La Vall d` Alba'),
#   ('provincia', 'Castellón'),
#   ('descripcion',
#    "El hostal se ubica en una masia restaurada de La Vall d'Alba (interior de Castellón), siendo herencia del negocio de restauración familiar. Somos un centro rural activo dinamizador de nuestro entorno a través de nuestra actividad. Ofrecemos a lo largo de todo el año un producto orientado al turista interesado en conocer nuestra cultura a través de la gastronomía y todo lo relacionado con ella: productos, variedades autóctonas, diversidad gastronómica,... La sostenibilidad, la calidad y una estrecha relación con el territorio y nuestro mundo rural son nuestras principales fortalezas."),
#   ('categoria', 'Restaurante  | Hotel'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=Edifici_(2)_371746.jpg&c=27532')],
#  [('id', 'casa_97'),
#   ('name', 'Refugio Marnes Casas Rurales'),
#   ('direccion', 'Ptd Marnes 20115  03720 Benissa'),
#   ('provincia', 'Alicante'),
#   ('descripcion',
#    'Refugio Marnes dispone de una variedad de opciones para que usted elija el alojamiento más apropiado en nuestra Casa Rural.\xa0\nEn La Finca de 20 hectáreas de Refugio Marnes Casas Rurales Alicante te proponemos B&B en la antigua granja llamada La Finca. Continuando y, escondida entre los árboles, se encuentra la encantadora cabaña La Ruina. Enclavado en un valle, en un lugar apartado, se encuentra la lujosa tienda glamping La Jaima.\xa0En las afueras de la finca Refugio Marnes se encuentra la casa de vacaciones independiente Finca Iris, una finca privada que puede acomodar hasta ocho personas con su propia piscina privada.\nDurante su estancia puede utilizar libremente la maravillosa piscina. Una piscina de azulejos de color verde esmeralda diseñada de tal manera que se integra en el entorno rural del Mediterráneo.'),
#   ('categoria',
#    'Casa Rural de alquiler integro  | Casa Rural por habitaciones  | Glamping'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=Guests-ejoying-the-veranda-on-the-32.jpg&c=31496')],
#  [('id', 'casa_98'),
#   ('name', 'Hotel Meridional'),
#   ('direccion', 'Av. de la Libertad, 64  03140 Guardamar del Segura'),
#   ('provincia', 'Alicante'),
#   ('descripcion',
#    'Disponemos de piscina-spa exterior, con zona infantil, zona de hidromasaje panorámica con vistas al mar, parking privado y de un prestigioso restaurante, "El Jardín", en el que degustar la auténtica cocina mediterránea, con terraza al aire libre y zona chill-out. El hotel también cuenta con varios salones para organizar todo tipo de eventos. Nuestras 52 habitaciones, modernas pero sin perder la calidez, se asoman al mar Mediterráneo desde amplias terrazas y disponen de todas las comodidades necesarias para hacer de su estancia una experiencia agradable. Todo rodeado de un entorno privilegiado.'),
#   ('categoria', 'Hotel'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=_DSC5489.15001598.jpg&c=23681')],
#  [('id', 'casa_99'),
#   ('name', 'Albergue La Pastora'),
#   ('direccion',
#    'Carretera VallibonaRossell km 10, Ermita de Sant Domingo  12315  Vallibona'),
#   ('provincia', 'Castellón'),
#   ('descripcion',
#    'Nos encontramos en el centro de uno de los parques naturales con mayor biodiversidad de la Comunidad Valenciana, con elevadas montañas y profundos barrancos que le confiere una diversidad de paisajes y rincones por descubrir. Un territorio idóneo para disfrutar de cada camino, senda y rincón. En apenas pocos metros del albergue encontraras carrascas y robles de más de 300 años, conservados con cariño y esmero por la gente local. Las municipios más cercanos, son Vallibona a 10 km al Oeste y Rosell a 14 km al Este. El albergue cuenta con 50 plazas distribuidas de la siguiente manera: 1 habitación doble adaptada, 2 habitaciones dobles, 3 habitaciones de 4 plazas y 4 habitaciones de 8 plazas. Cada habitación tiene su cuarto de baño, dotado con inodoro y ducha o bañera. Además disponemos de salas comunes para los alberguistas, salón con estufa de leña, pequeña biblioteca, sala de juegos, salita infantil... Todo esto acompañado de un gran espacio natural para conocer.\nEn constante crecimiento,además del alojamiento podreís ver los trabajos en exterior que realizamos; estamos en camino de la recuperación total de los antiguos bancales de tierra de cultivo de la ermita, además gracias a la colaboración de propietarios privados disponemos de un espacio adherido al ermitorio para utilizar como gallinero de gallinas autóctonas, y sala multiusos recuperada en bioconstrucción.\n'),
#   ('categoria', 'Albergue'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=Vista_edific444.7009.jpg&c=2527')],
#  [('id', 'casa_100'),
#   ('name', 'Marem - casa rural sostenible'),
#   ('direccion', 'C/ Julio Castroviejo, 10  26124  El Rasillo de Cameros  L'),
#   ('provincia', 'Rioja'),
#   ('descripcion',
#    'La casa rural MAREM es una pequeña casa en el casco del municipio de El Rasillo que pretende dar alojamiento a personas, parejas, grupos de amigos y familias que quieran conocer la zona y llevar a cabo actividades en torno a la agroecología. Durante la estancia se propone una vivencia sostenible basada en el conocimiento de la zona, su patrimonio y su paisaje, el cuidado del agua, la gestión de los residuos y la minimización del consumo energético, el acercamiento a la agroecología y el cuidado de los recursos materiales y personales.\xa0\nTenemos varias posibilidades de alojamiento: alquilar habitaciones (opción alojamiento compartido) o bien la planta 1 y la planta 2 completas (opción alojamiento completo). Nosotras tenemos un espacio en la planta baja dedicado también a talleres y actividades y un jardín con huerta anexado a la casa.\n\xa0'),
#   ('categoria', 'Casa Rural por habitaciones'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=CASA-_RURAL-_MAREM_-_EL_RASILLO_565976.jpg&c=30871')],
#  [('id', 'casa_101'),
#   ('name', 'Viña Ijalba'),
#   ('direccion', 'Ctra. Pamplona, km 1  26006 Logroño  L'),
#   ('provincia', 'Rioja'),
#   ('descripcion', '\xa0'),
#   ('categoria', 'Finca familiar, bodega, almazara'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=1002199_10151821318563641_1893051458.jpg&c=28651')],
#  [('id', 'casa_102'),
#   ('name', 'Casa Rural Melones'),
#   ('direccion', 'Avda. de Madrid, 109  28189  Patones'),
#   ('provincia', 'Madrid'),
#   ('descripcion',
#    'Teníamos un sueño, rehabilitar la antigua cuadra donde la familia Melones guardaba a sus animales y transformarla en una casa rural ecológica. Se ha hecho realidad y Casa rural Melones es un alojamiento con siete habitaciones, de los cuales una es adaptada a personas con discapacidad física. Tiene una zona interior de uso común con sala de estar con chimenea y biblioteca y un amplio comedor. También una zona exterior con barbacoa. Se puede alquilar por habitaciones con desayuno incluido o alquiler íntegro con capacidad para 14-18 personas. Además del alojamiento contamos con un taller de cerámica, una colección de cactus y crasas, gallinero y pequeño huerto de autoconsumo'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=zonas_comun419422.jpg&c=29425')],
#  [('id', 'casa_103'),
#   ('name', 'Granja Prados Montes'),
#   ('direccion', 'Travesía del Turco, 12  28190 Montejo de la Sierra'),
#   ('provincia', 'Madrid'),
#   ('descripcion',
#    'Granja Prados Montes es una granja familiar cuyo objetivo es generar un agrosistema sostenible unido a una forma de vida ligada al territorio y al mantenimiento de usos y costumbres. Ofrecemos visitas para familias y adultos y venta de productos en la propia explotación, así como cursos con distinta temática dependiendo de la época del año.\xa0Desde julio de 2019 estamos en reconversión a ecológico certificado en apicultura y agricultura; además nuestro compromiso es el de manejar nuestro ganado en extensivo y con piensos libres de transgénicos. Hemos firmado un contrato de custodia del territorio con la Fundación Internacional para la Restauración de Ecosistemas, que nos avala como una explotación que lleva a cabo todas las buenas prácticas posibles para mejorar y convivir con la biodiversidad natural del entorno.'),
#   ('categoria', 'Finca familiar, bodega, almazara'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=55523523_2302276023395501_8137236651.jpg&c=22428')],
#  [('id', 'casa_104'),
#   ('name', 'Cortijo Los Gorros Ecofinca'),
#   ('direccion', 'Los Gorros  30440 Moratalla'),
#   ('provincia', 'Murcia'),
#   ('descripcion',
#    'El Cortijo Los Gorros es un oasis en la naturaleza que funciona con energias renovables, un espacio perfecto para desconectar del estrés y la rutina porque, gracias a su ubicación en plena sierra de Los Álamos de Moratalla (Murcia), ofrece multitud de posibilidades para disfrutar de la naturaleza.'),
#   ('categoria',
#    'Casa Rural de alquiler integro  | Actividad en la Naturaleza'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=Los_Gorros_Ecofinca_Moratalla3648.jpg&c=28739')],
#  [('id', 'casa_105'),
#   ('name', 'Centro de Agroecología y Medio Ambiente'),
#   ('direccion', 'Paraje de La Rafa, s/n  30180 Bullas'),
#   ('provincia', 'Murcia'),
#   ('descripcion',
#    'Estudio bioclimático, de 60 m2, completamente equipado y destinado en principio a 4 personas como máximo.\nSituado en el Centro de Agroecología y Medio Ambiente, cuenta con amplia extensión de diferentes cultivos, asi como de sendas temáticas que explican dichos cultivos y un humedal para el avistamiento de aves. Lugar perfecto para descansar y adentrarse en el medio ambiente.'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=ceama146.jpg&c=28947')],
#  [('id', 'casa_106'),
#   ('name', 'Finca las Nieves'),
#   ('direccion',
#    'Camino Ermita Vieja nº 18. Finca las Nieves.  30439 El Escobar. Cehegín'),
#   ('provincia', 'Murcia'),
#   ('descripcion', '\n\n'),
#   ('categoria', 'Casa Rural de alquiler integro'),
#   ('image',
#    'https://www.ecotur.es/v_portal/inc/imagen.asp?f=photo58818197880434655089694.jpg&c=24223')]]

# %%
df = pd.DataFrame([[x[0][1],
                    x[1][1],
                    x[2][1],
                    x[3][1],
                    x[4][1],
                    x[5][1],
                    x[6][1]
                   ] for x in lista_casas],
                  columns = ['id',
                             'name',
                             'direccion',
                             'provincia',
                             'descripcion',
                             'categoria',
                             'imagen'])

# %%
df
# Out:
#            id                                     name  \
# 0      casa_1                      La Posada El Candil
# 1      casa_2          Cortijo La Molina, Cabo de Gata
# 2      casa_3            Cortijo Balzaín Casas Rurales
# 3      casa_4                          Finca Montefrío
# 4      casa_5                  O Chardinet d'a Formiga
# ..        ...                                      ...
# 101  casa_102                       Casa Rural Melones
# 102  casa_103                     Granja Prados Montes
# 103  casa_104              Cortijo Los Gorros Ecofinca
# 104  casa_105  Centro de Agroecología y Medio Ambiente
# 105  casa_106                         Finca las Nieves
#
#                                              direccion provincia  \
# 0    Paraje El Angulo s/n (Carretera AL5406 Km 2)  ...   Almería
# 1                 Calle San Miguel, s/n  04151 Pujaire   Almería
# 2         Ctra. de Cumbres Verdes km.2  18140 La Zubia   Granada
# 3           Finca Montefrío, aptdo 15  21230 Cortegana    Huelva
# 4                  C/Única, s/n, Charo  22336 La Fueva    Huesca
# ..                                                 ...       ...
# 101               Avda. de Madrid, 109  28189  Patones    Madrid
# 102  Travesía del Turco, 12  28190 Montejo de la Si...    Madrid
# 103                        Los Gorros  30440 Moratalla    Murcia
# 104               Paraje de La Rafa, s/n  30180 Bullas    Murcia
# 105  Camino Ermita Vieja nº 18. Finca las Nieves.  ...    Murcia
#
#                                            descripcion  \
# 0    La Posada del Candil nos ofrece 5 Casas distri...
# 1    www.cortijolamolina.es\nEl Cortijo La Molina, ...
# 2    Cortijo Balzaín, se encuentra situado en el Pa...
# 3    En Finca Montefrio ofrecemos la oportunidad de...
# 4    Casa rural en el Pirineo aragonés cerca de Par...
# ..                                                 ...
# 101  Teníamos un sueño, rehabilitar la antigua cuad...
# 102  Granja Prados Montes es una granja familiar cu...
# 103  El Cortijo Los Gorros es un oasis en la natura...
# 104  Estudio bioclimático, de 60 m2, completamente ...
# 105                                               \n\n
#
#                                              categoria  \
# 0                       Casa Rural de alquiler integro
# 1                       Casa Rural de alquiler integro
# 2                       Casa Rural de alquiler integro
# 3                       Casa Rural de alquiler integro
# 4                          Casa Rural por habitaciones
# ..                                                 ...
# 101                     Casa Rural de alquiler integro
# 102                   Finca familiar, bodega, almazara
# 103  Casa Rural de alquiler integro  | Actividad en...
# 104                     Casa Rural de alquiler integro
# 105                     Casa Rural de alquiler integro
#
#                                                 imagen
# 0    https://www.ecotur.es/v_portal/inc/imagen.asp?...
# 1    https://www.ecotur.es/v_portal/inc/imagen.asp?...
# 2    https://www.ecotur.es/v_portal/inc/imagen.asp?...
# 3    https://www.ecotur.es/v_portal/inc/imagen.asp?...
# 4    https://www.ecotur.es/v_portal/inc/imagen.asp?...
# ..                                                 ...
# 101  https://www.ecotur.es/v_portal/inc/imagen.asp?...
# 102  https://www.ecotur.es/v_portal/inc/imagen.asp?...
# 103  https://www.ecotur.es/v_portal/inc/imagen.asp?...
# 104  https://www.ecotur.es/v_portal/inc/imagen.asp?...
# 105  https://www.ecotur.es/v_portal/inc/imagen.asp?...
#
# [106 rows x 7 columns]

# %%
direccion = list(df.direccion)

# %%
lat = []
lon = []
for i in direccion:
    from geopy.geocoders import Nominatim
    geolocator = Nominatim(user_agent="_______")
    location = geolocator.geocode(i)
    try:
        lat.append(location.latitude)
        lon.append(location.longitude)

    except:
        lat.append(None)
        lon.append(None)

# %%
df = df.assign(latitude = lat)
df = df.assign(longitude = lon)

# %%
df.to_csv('ecotur2.csv')

# %%
df.count()
# Out:
# id             106
# name           106
# direccion      106
# provincia      106
# descripcion    106
# categoria       99
# imagen         106
# latitude        29
# longitude       29
# dtype: int64

# %%
# Out:
# [[('id', 'casa_1'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tUlle Gorri \r\n                                            '),
#   ('direccion', '\nES-EU/051/00031\n'),
#   ('telefono', '\nES-EU/051/00031\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_2'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tLa Posada de San Marcos, Millán Arkwright SL\r\n                                            '),
#   ('direccion', '\nES-AN/051/00001\n'),
#   ('telefono', '\nES-AN/051/00001\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_3'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tTAKE HOSTEL CONIL\r\n                                            '),
#   ('direccion', '\nES-AN/051/00002\n'),
#   ('telefono', '\nES-AN/051/00002\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_4'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tTECNIBER, SA\r\n                                            '),
#   ('direccion', '\nES-CAT/051/001\n'),
#   ('telefono', '\nES-CAT/051/001\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_5'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tAGROTURISMO ABAIENEA\r\n                                            '),
#   ('direccion', '\nES-EU/051/00019\n'),
#   ('telefono', '\nES-EU/051/00019\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_6'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tAgroturismo Bisalde\r\n                                            '),
#   ('direccion', '\nES-EU/051/00027\n'),
#   ('telefono', '\nES-EU/051/00027\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_7'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tAgroturismo Madarian\r\n                                            '),
#   ('direccion', '\nES-EU/051/00012\n'),
#   ('telefono', '\nES-EU/051/00012\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_8'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tApartamentos Rurales Casa Lafuente\r\n                                            '),
#   ('direccion', '\nES-EU/051/00024\n'),
#   ('telefono', '\nES-EU/051/00024\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_9'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tCamping & Bungalows Zumaia\r\n                                            '),
#   ('direccion', '\nES-EU/051/00002\n'),
#   ('telefono', '\nES-EU/051/00002\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_10'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tCamping el Roble Verde\r\n                                            '),
#   ('direccion', '\nES-EU/051/00005\n'),
#   ('telefono', '\nES-EU/051/00005\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_11'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tArrizurieta\r\n                                            '),
#   ('direccion', '\nES-EU/051/00018\n'),
#   ('telefono', '\nES-EU/051/00018\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_12'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tCasa Rural Errotabarri\r\n                                            '),
#   ('direccion', '\nES-EU/051/00025\n'),
#   ('telefono', '\nES-EU/051/00025\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_13'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tCasa Rural Etxegorri\r\n                                            '),
#   ('direccion', '\nES-EU/051/00009\n'),
#   ('telefono', '\nES-EU/051/00009\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_14'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tZadorra Etxea\r\n                                            '),
#   ('direccion', '\nES-EU/051/00021\n'),
#   ('telefono', '\nES-EU/051/00021\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_15'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tDOLAREA\r\n                                            '),
#   ('direccion', '\nES-EU/051/00006\n'),
#   ('telefono', '\nES-EU/051/00006\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_16'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tHotel Amalurra\r\n                                            '),
#   ('direccion', '\nES-EU/051/00026\n'),
#   ('telefono', '\nES-EU/051/00026\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_17'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tHOTEL APARTAMENTO RURAL ATXURRA\r\n                                            '),
#   ('direccion', '\nES-EU/051/00023\n'),
#   ('telefono', '\nES-EU/051/00023\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_18'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tHotel Imaz\r\n                                            '),
#   ('direccion', '\nES-EU/051/00020\n'),
#   ('telefono', '\nES-EU/051/00020\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_19'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tHotel Rural Aribe - Arrigorri Restauracion SL\r\n                                            '),
#   ('direccion', '\nES-NA/025/001\n'),
#   ('telefono', '\nES-NA/025/001\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_20'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tHotel Urune\r\n                                            '),
#   ('direccion', '\nES-EU/051/00028\n'),
#   ('telefono', '\nES-EU/051/00028\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_21'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tLA CASA DE MADERA\r\n                                            '),
#   ('direccion', '\nES-EU/051/00003\n'),
#   ('telefono', '\nES-EU/051/00003\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_22'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tLegaire Etxea\r\n                                            '),
#   ('direccion', '\nES-EU/051/00030\n'),
#   ('telefono', '\nES-EU/051/00030\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_23'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tLete Apartamentuak\r\n                                            '),
#   ('direccion', '\nES-EU/051/00013\n'),
#   ('telefono', '\nES-EU/051/00013\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_24'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tAlbergue Juvenil Ulia\r\n                                            '),
#   ('direccion', '\nES-EU/051/00011\n'),
#   ('telefono', '\nES-EU/051/00011\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_25'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tCasa rural Tierra y Madera\r\n                                            '),
#   ('direccion', '\nES-EU/051/00035\n'),
#   ('telefono', '\nES-EU/051/00035\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_26'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tHOTEL ZERUPE\r\n                                            '),
#   ('direccion', '\nES-EU/051/00034\n'),
#   ('telefono', '\nES-EU/051/00034\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_27'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tAgroturismo Lurdeia\r\n                                            '),
#   ('direccion', '\nES-EU/051/00010\n'),
#   ('telefono', '\nES-EU/051/00010\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_28'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tAzala\r\n                                            '),
#   ('direccion', '\nES-EU/051/00001\n'),
#   ('telefono', '\nES-EU/051/00001\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_29'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tAgroturismo Iabiti-Aurrekoa\r\n                                            '),
#   ('direccion', '\nES-EU/051/00022\n'),
#   ('telefono', '\nES-EU/051/00022\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_30'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tCamping Angosto\r\n                                            '),
#   ('direccion', '\nES-EU/051/00016\n'),
#   ('telefono', '\nES-EU/051/00016\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_31'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tHotel Casa del Patrón\r\n                                            '),
#   ('direccion', '\nES-EU/051/00015\n'),
#   ('telefono', '\nES-EU/051/00015\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_32'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tAGROTURISMO ARKAIA\r\n                                            '),
#   ('direccion', '\nES-EU/051/00007\n'),
#   ('telefono', '\nES-EU/051/00007\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_33'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tAGROTURISMO IBARRE\r\n                                            '),
#   ('direccion', '\nES-EU/051/00032\n'),
#   ('telefono', '\nES-EU/051/00032\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_34'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tUrresillo Landetxea\r\n                                            '),
#   ('direccion', '\nES-EU/051/00004\n'),
#   ('telefono', '\nES-EU/051/00004\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_35'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tGorosarri Landetxea\r\n                                            '),
#   ('direccion', '\nES-EU/051/00008\n'),
#   ('telefono', '\nES-EU/051/00008\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_36'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tAlvarella Ecoturismo\r\n                                            '),
#   ('direccion', '\nESGA/051/001\n'),
#   ('telefono', '\nESGA/051/001\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_37'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tCAMPING EL BERGUEDA\r\n                                            '),
#   ('direccion', '\nES-CAT/051/002\n'),
#   ('telefono', '\nES-CAT/051/002\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_38'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tCAMPS DE VILARRASA-CAL CANDI\r\n                                            '),
#   ('direccion', '\nES-CAT/051/005\n'),
#   ('telefono', '\nES-CAT/051/005\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_39'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tMIREIA FONT I VIDAL\r\n                                            '),
#   ('direccion', '\nES-CAT/051/010\n'),
#   ('telefono', '\nES-CAT/051/010\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_40'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tTURYE, S.A.\r\n                                            '),
#   ('direccion', '\nES-IB/25/03\n'),
#   ('telefono', '\nES-IB/25/03\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_41'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tEllauri Hotel\r\n                                            '),
#   ('direccion', '\nES-EU/051/00017\n'),
#   ('telefono', '\nES-EU/051/00017\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_42'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tPOBLE NOU RESORT, SL\r\n                                            '),
#   ('direccion', '\nES-CAT/051/007\n'),
#   ('telefono', '\nES-CAT/051/007\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_43'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tCARPE VITAM, SL\r\n                                            '),
#   ('direccion', '\nES-CAT/051/008\n'),
#   ('telefono', '\nES-CAT/051/008\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_44'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tHotel Arbe\r\n                                            '),
#   ('direccion', '\nES-EU/051/00029\n'),
#   ('telefono', '\nES-EU/051/00029\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_45'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tBELINDA JANE PARRIS\r\n                                            '),
#   ('direccion', '\nES-CAT/051/006\n'),
#   ('telefono', '\nES-CAT/051/006\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_46'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tLLUÍS CORBELLA JORDI\r\n                                            '),
#   ('direccion', '\nES-CAT/051/003\n'),
#   ('telefono', '\nES-CAT/051/003\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_47'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tPERE SOLÉ ROVIRA\r\n                                            '),
#   ('direccion', '\nES-CAT/051/004\n'),
#   ('telefono', '\nES-CAT/051/004\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_48'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tPensión Mélida Ostatua\r\n                                            '),
#   ('direccion', '\nES-EU/051/00014\n'),
#   ('telefono', '\nES-EU/051/00014\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_49'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tALTERNATIVE CREATION SL\r\n                                            '),
#   ('direccion', '\nES-CAT/051/009\n'),
#   ('telefono', '\nES-CAT/051/009\n'),
#   ('web', None),
#   ('imagen', 'None')],
#  [('id', 'casa_50'),
#   ('name',
#    '\n\r\n                                            \tEcolabel\r\n                                            \t \r\n                                            \tSELVAVENTURA, S.L.\r\n                                            '),
#   ('direccion', '\nES-EU/051/00033\n'),
#   ('telefono', '\nES-EU/051/00033\n'),
#   ('web', None),
#   ('imagen', 'None')]]

# %%
# La web tiene 6 páginas con casas rurales listadas
pages = np.arange(1, 14)
count = 1
lista_casas = []

for page in pages:
    
    count_casa = 1 #Para el print
    URL = 'http://www.redeuroparc.org/actividades/carta-europea-turismo-sostenible/empresas-adheridas-a-la-cets/consulta?field_cets_enp_tid=All&field_comunidades_autonomas_tid=All&title=&field_cets_actividad_tid=All&status=1&page='+ str(page)
    r = requests.get(URL)
    soup = BeautifulSoup(r.text, 'lxml')
    
    # Guardamos lista de cervezas y recorremos
    casas_grid = soup.find_all(class_='views-field views-field-title')
    #print(len(cervezas_grid))

    for casa in casas_grid:
        
        print('Casa {} de {}, pag {}/{}'.format(
            count_casa, len(casas_grid), page, len(pages)
        ))

        URL_casas = 'http://www.redeuroparc.org' + casa.find('a')['href']
        r = requests.get(URL_casas)
        soup_casa = BeautifulSoup(r.text, 'lxml')
        
        # Definimos id para cada cerveza
        id_casa = 'casa_' + str(count)
        
        # Nombre
        name = soup_casa.find(class_='col-md-12')['H1']
        #print(name)
        
        # Direccion 
        direccion = soup_casa.find(class_='field-item even').text
        #print(price)
        
        # Categoría
        
        try:
            categoria = soup_casa.find(class_='field-label').text
        
        except:
            categoria = None

        #print(price)
        
        #Telefono 
        telefono = soup_casa.find(class_='field-item even').text
                
        # Imagen
        div_image = soup_casa.find(class_='field-item even')
        
        image = div_image.find('img').attrs['src']
        #print(image)
        
        #print(ean)
        
       # Agregamos a la lista
        lista_casas.append([
            ('id', id_casa),
            ('name', name), 
            ('direccion', direccion),
            ('telefono', telefono),
            ('categoria', categoria),
            ('image', image),
            ])        
        
        
        # Pasamos al siguiente id
        count += 1
        
        count_casa += 1
