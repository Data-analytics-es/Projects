# %% [markdown]
# # Scraping Ecotur

# %%
# Importamos librerías
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import pandas as pd

# %%
pages = np.arange(1, 4)
count = 1
lista_acts = []

for page in pages:
    
    count_act = 1 #Para el print
    URL = 'https://www.ecotur.es/v_portal/busqueda/index.asp?provincia=&entornobs=&serviciosbs=&npag=' + str(page) + '&sellosbs=287'
    r = requests.get(URL)
    soup = BeautifulSoup(r.text, 'lxml')
    
    # Guardamos lista de actividades y recorremos
    acts_grid = soup.find_all(class_='fot_min')
        
    for act in acts_grid:

        print('Actividad {} de {}, pag {}/{}'.format(
            count_act, len(acts_grid), page, len(pages)
        ))

        URL_acts = 'https://www.ecotur.es' + act.find('a')['href']
        r = requests.get(URL_acts)
        soup_act = BeautifulSoup(r.text, 'lxml')

        # Definimos id para cada actividad
        id_act = 'actividad_' + str(count)

        # Nombre
        name = soup_act.find(class_='titulo blq fs_21_32 mar0').text
        #print(name)

        # Direccion 
        direccion_total = soup_act.find(class_='blq mart16 fs_14_16 lh_140').text.rsplit(' ',1)
        direccion = direccion_total[0][:-1]
        provincia = direccion_total[1]
        #print(price)

        # Categoría

        try:
            categoria = soup_act.find(class_='bl_izq mart2 fs_12_14').text.replace('\xa0\r\n                ', '')
            categoria = categoria.replace('\r\n              ', '')
            categoria = categoria.replace('Categoría:', '')

        except:
            categoria = None

        #print(price)

        #descripcion 
        descripcion = soup_act.find(class_='blq fs_14_18 colgen lh_140').text

        # Imagen
        div_image = soup_act.find(class_='fot_min fot_centro marb10')

        image = 'https://www.ecotur.es' + div_image.find('img').attrs['src']
        #print(image)

        #print(ean)

       # Agregamos a la lista
        lista_acts.append([
            ('id', id_act),
            ('name', name), 
            ('direccion', direccion),
            ('provincia', provincia),
            ('descripcion', descripcion),
            ('categoria', categoria),
            ('image', image),
            ])        


        # Pasamos al siguiente id
        count += 1
        count_act += 1
# Out:
# Actividad 1 de 8, pag 1/3
# Actividad 2 de 8, pag 1/3
# Actividad 3 de 8, pag 1/3
# Actividad 4 de 8, pag 1/3
# Actividad 5 de 8, pag 1/3
# Actividad 6 de 8, pag 1/3
# Actividad 7 de 8, pag 1/3
# Actividad 8 de 8, pag 1/3
# Actividad 1 de 7, pag 2/3
# Actividad 2 de 7, pag 2/3
# Actividad 3 de 7, pag 2/3
# Actividad 4 de 7, pag 2/3
# Actividad 5 de 7, pag 2/3
# Actividad 6 de 7, pag 2/3
# Actividad 7 de 7, pag 2/3
# Actividad 1 de 6, pag 3/3
# Actividad 2 de 6, pag 3/3
# Actividad 3 de 6, pag 3/3
# Actividad 4 de 6, pag 3/3
# Actividad 5 de 6, pag 3/3
# Actividad 6 de 6, pag 3/3

# %%
df = pd.DataFrame([[x[0][1],
                    x[1][1],
                    x[2][1],
                    x[3][1],
                    x[4][1],
                    x[5][1],
                    x[6][1]
                   ] for x in lista_acts],
                  columns = ['id',
                             'name',
                             'direccion',
                             'provincia',
                             'descripcion',
                             'categoria',
                             'imagen'])

# %%
df
# Out:
#               id                                   name  \
# 0    actividad_1                  Casas Rurales de Caín
# 1    actividad_2                 Ecomuséu Ca l'Asturcón
# 2    actividad_3                       Tenada del Monte
# 3    actividad_4                La Casa del Naturalista
# 4    actividad_5              Hotel Enoturismo Mainetes
# 5    actividad_6                     Finca Buenos Aires
# 6    actividad_7                      Vereda la Mariela
# 7    actividad_8                        Ecoaldea Illari
# 8    actividad_9                              Zona Bici
# 9   actividad_10  Rincón La Huella Verde - Habitaciones
# 10  actividad_11                              Go2Nature
# 11  actividad_12             Regiones agencia de viajes
# 12  actividad_13                      Molino de Jaranda
# 13  actividad_14            Cortijo Los Gorros Ecofinca
# 14  actividad_15                          Quei Vitorino
# 15  actividad_16                          AgroSilvestre
# ...

# %% [markdown]
# ## Conversión de dirección en coordenadas

# %%
direccion = list(df.direccion)

# %%
from geopy.geocoders import Nominatim
lat = []
lon = []
for i in direccion:
    geolocator = Nominatim(user_agent="Kerstin")
    location = geolocator.geocode(i)
    try:
        lat.append(location.latitude)
        lon.append(location.longitude)

    except:
        lat.append(None)
        lon.append(None)

    #time.sleep(1)

# %%
df = df.assign(latitude = lat)
df = df.assign(longitude = lon)

# %%
df.to_csv('ecotur_act.csv')
